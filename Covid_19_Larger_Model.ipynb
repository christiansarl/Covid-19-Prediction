# %% [markdown]
# ## OBJECTIVES ##
# Larger Models
#
# *In contrast to the previous study that only used 3 variables to predict the mortality of the patients of COVID-19, this script will perform feature selection to select more variables before running the model to predict the
# mortality of COVID-19 patients.*

# %%
import pandas as pd
import math
import numpy as np
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.feature_selection import RFECV
from sklearn.model_selection import ShuffleSplit, cross_validate
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn import svm
import matplotlib.pyplot as plt
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_4860\262213884.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_excel('time_series_375_preprocess_en.xls')
data.head(3)
# Out:
#    PATIENT_ID             RE_DATE  age  gender      Admission time  \
# 0         1.0 2020-01-31 01:09:00   73       1 2020-01-30 22:12:47
# 1         NaN 2020-01-31 01:25:00   73       1 2020-01-30 22:12:47
# 2         NaN 2020-01-31 01:44:00   73       1 2020-01-30 22:12:47
#
#        Discharge time  outcome  Hypersensitive cardiac troponinI  hemoglobin  \
# 0 2020-02-17 12:40:09        0                               NaN         NaN
# 1 2020-02-17 12:40:09        0                               NaN       136.0
# 2 2020-02-17 12:40:09        0                               NaN         NaN
#
#    Serum chloride  ...  mean corpuscular hemoglobin   \
# 0             NaN  ...                           NaN
# 1             NaN  ...                          31.9
# 2           103.1  ...                           NaN
#
#    Activation of partial thromboplastin time  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
#
#    Hypersensitive c-reactive protein  HIV antibody quantification  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                               43.1                          NaN
#
#    serum sodium  thrombocytocrit  ESR  glutamic-pyruvic transaminase  eGFR  \
# 0           NaN              NaN  NaN                            NaN   NaN
# 1           NaN             0.12  NaN                            NaN   NaN
# 2         137.7              NaN  NaN                           16.0  46.6
#
#    creatinine
# 0         NaN
# 1         NaN
# 2       130.0
#
# [3 rows x 81 columns]

# %%
data = data.drop(columns=['RE_DATE', 'Admission time', 'Discharge time'])
data = data.rename(columns={"PATIENT_ID": "id"})
data = data.ffill().drop_duplicates('id',keep='last')
data.head(3)
# Out:
#      id  age  gender  outcome  Hypersensitive cardiac troponinI  hemoglobin  \
# 23  1.0   73       1        0                              19.9       131.0
# 52  2.0   61       1        0                               1.9       149.0
# 70  3.0   70       2        0                               1.9       126.0
#
#     Serum chloride  Prothrombin time  procalcitonin  eosinophils(%)  ...  \
# 23           100.0              12.4           0.09             1.7  ...
# 52            98.1              12.3           0.09             0.1  ...
# 70           102.2              13.6           0.06             0.1  ...
#
#     mean corpuscular hemoglobin   Activation of partial thromboplastin time  \
# 23                          32.3                                       38.9
# 52                          32.2                                       36.0
# 70                          33.3                                       34.8
#
#     Hypersensitive c-reactive protein  HIV antibody quantification  \
# 23                                2.6                         0.09
# 52                               27.4                         0.09
# 70                                3.6                         0.10
#
#     serum sodium  thrombocytocrit   ESR  glutamic-pyruvic transaminase  eGFR  \
# 23         142.7             0.16  41.0                           30.0  74.7
# 52         137.4             0.27  40.0                           22.0  94.6
# 70         143.2             0.23  29.0                           67.0  84.6
#
#     creatinine
# 23        88.0
# 52        74.0
# 70        64.0
#
# [3 rows x 78 columns]

# %%
#Now we normalize
normalized=(data-data.mean())/data.std()
X = normalized.drop(['id', 'outcome'], axis=1)
y = data['outcome']
#We remove some NaNs.
X.dropna(axis=1, inplace=True)

# %% [markdown]
# **RFCV(Recursive feature elimination with cross-validation to select features)**
#
# *which is the feature selection strategy that uses the learned model and classification accuracy to try to find the best feature subset.  The model was using a random forest classifier with 5-fold cross-validation by ranking the features based on their importance, deleting the least important features, and fitting the model again.*

# %%
model = RFECV(RandomForestClassifier(n_jobs=-1), cv=5)
print("created model, will now fit.")
model.fit(X, y)
# Out:
# created model, will now fit.
# RFECV(cv=5, estimator=RandomForestClassifier(n_jobs=-1))

# %%
print("Total number of Features: %s" % (model.n_features_))
print("Selected Features: %s" % X.columns[model.support_])
print("Feature Rankings: %s" % (model.ranking_))
# Out:
# Total number of Features: 19
# Selected Features: Index(['Hypersensitive cardiac troponinI', 'Prothrombin time', 'procalcitonin',
#        'eosinophils(%)', 'albumin', 'Platelet count', 'monocytes(%)',
#        'neutrophils(%)', 'Prothrombin activity', 'Urea', 'lymphocyte count',
#        'glucose', '(%)lymphocyte', 'D-D dimer', 'aspartate aminotransferase',
#        'Amino-terminal brain natriuretic peptide precursor(NT-proBNP)',
#        'Lactate dehydrogenase', 'International standard ratio',
#        'Hypersensitive c-reactive protein'],
#       dtype='object')
# Feature Rankings: [11 46  1 30  4  1  1  1 20  1 28 43  1  1 37 15  1 13 39  1 48 33 38 29
#  40 24  1  1 47 31 14 19 42  1 18  6 22  5 26 27  1 41  1  7  1 25 12  3
#   1  1 36 35 16 32 49  1 34 44  8  1 23 10  9 45 21  2 17]

# %%
train = data.filter(['id','outcome','Hypersensitive cardiac troponinI', 'Prothrombin time', 'procalcitonin',
       'eosinophils(%)', 'albumin', 'Platelet count', 'monocytes(%)',
       'neutrophils(%)', 'Prothrombin activity', 'Urea', 'lymphocyte count',
       'glucose', '(%)lymphocyte', 'D-D dimer', 'aspartate aminotransferase',
       'Amino-terminal brain natriuretic peptide precursor(NT-proBNP)',
       'Lactate dehydrogenase', 'International standard ratio',
       'Hypersensitive c-reactive protein'])
train.head(10)
# Out:
#        id  outcome  Hypersensitive cardiac troponinI  Prothrombin time  \
# 23    1.0        0                              19.9              12.4
# 52    2.0        0                               1.9              12.3
# 70    3.0        0                               1.9              13.6
# 84    4.0        0                               4.8              16.3
# 105   5.0        0                               5.6              14.6
# 119   6.0        0                              19.7              12.4
# 139   7.0        0                               2.4              11.5
# 166   8.0        0                               3.6              13.0
# 183   9.0        0                               3.6              14.0
# 209  10.0        0                               3.3              12.1
#
#      procalcitonin  eosinophils(%)  albumin  Platelet count  monocytes(%)  \
# 23            0.09             1.7     37.6           141.0           7.9
# 52            0.09             0.1     37.2           283.0           5.7
# 70            0.06             0.1     38.4           238.0           6.1
# 84            0.38             2.5     34.1           300.0           8.6
# 105           0.02             3.0     39.5           356.0           7.4
# 119           0.05             2.4     30.6           239.0           8.2
# 139           0.04             0.0     28.6           238.0           8.3
# 166           0.02             3.2     39.1           167.0           9.3
# 183           0.02             2.0     39.5           209.0           9.0
# 209           0.11             1.0     33.3           233.0           8.1
#
#      neutrophils(%)  ...  Urea  lymphocyte count  glucose  (%)lymphocyte  \
# 23             64.3  ...  6.50              2.50     6.75           25.9
# 52             84.7  ...  3.50              0.95    11.32            9.2
# 70             66.4  ...  4.22              2.10     9.42           27.3
# 84             72.1  ...  3.60              1.12     5.78           16.5
# 105            65.5  ...  3.00              1.88     4.84           23.6
# 119            58.1  ...  5.20              0.91     5.11           31.0
# 139            78.3  ...  5.10              1.27    12.67           13.3
# 166            49.4  ...  2.80              2.00     4.36           37.2
# 183            66.8  ...  3.20              1.31     4.83           21.9
# 209            66.3  ...  3.80              2.15     4.07           24.5
#
#      D-D dimer  aspartate aminotransferase  \
# 23        0.92                        23.0
# 52        0.44                        15.0
# 70        0.98                        20.0
# 84        1.26                        28.0
# 105       0.42                        13.0
# 119       0.60                        20.0
# 139       0.31                        22.0
# 166       0.57                        17.0
# 183       0.47                        19.0
# 209       0.24                        22.0
#
#      Amino-terminal brain natriuretic peptide precursor(NT-proBNP)  \
# 23                                                60.0
# 52                                                28.0
# 70                                                28.0
# 84                                               152.0
# 105                                                5.0
# 119                                              645.0
# 139                                                9.0
# 166                                                5.0
# 183                                                5.0
# 209                                                9.0
#
#      Lactate dehydrogenase  International standard ratio  \
# 23                   206.0                          0.92
# 52                   282.0                          0.92
# 70                   226.0                          1.04
# 84                   249.0                          1.29
# 105                  179.0                          1.13
# 119                  231.0                          0.92
# 139                  313.0                          0.84
# 166                  181.0                          0.98
# 183                  170.0                          1.07
# 209                  220.0                          0.89
#
#      Hypersensitive c-reactive protein
# 23                                 2.6
# 52                                27.4
# 70                                 3.6
# 84                                14.5
# 105                                0.8
# 119                                0.3
# 139                                1.5
# 166                                0.6
# 183                                3.2
# 209                                2.3
#
# [10 rows x 21 columns]

# %%
normalized_train=(train-train.mean())/train.std()
# little ugly but we want to maybe preserve id
normalized_train['id'] = train['id']
normalized_train.head(10)
# Out:
#        id   outcome  Hypersensitive cardiac troponinI  Prothrombin time  \
# 23    1.0 -0.929173                         -0.145786         -0.574903
# 52    2.0 -0.929173                         -0.150104         -0.590999
# 70    3.0 -0.929173                         -0.150104         -0.381752
# 84    4.0 -0.929173                         -0.149408          0.052838
# 105   5.0 -0.929173                         -0.149217         -0.220793
# 119   6.0 -0.929173                         -0.145834         -0.574903
# 139   7.0 -0.929173                         -0.149984         -0.719766
# 166   8.0 -0.929173                         -0.149696         -0.478328
# 183   9.0 -0.929173                         -0.149696         -0.317369
# 209  10.0 -0.929173                         -0.149768         -0.623191
#
#      procalcitonin  eosinophils(%)   albumin  Platelet count  monocytes(%)  \
# 23       -0.238867        0.659576  0.790619       -0.465731      0.316872
# 52       -0.238867       -0.613737  0.727356        0.833865     -0.160868
# 70       -0.245580       -0.613737  0.917145        0.422021     -0.074006
# 84       -0.173967        1.296233  0.237068        0.989450      0.468880
# 105      -0.254532        1.694143  1.091118        1.501967      0.208294
# 119      -0.247818        1.216651 -0.316484        0.431173      0.382018
# 139      -0.250056       -0.693319 -0.632799        0.422021      0.403733
# 166      -0.254532        1.853307  1.027855       -0.227777      0.620888
# 183      -0.254532        0.898322  1.091118        0.156610      0.555741
# 209      -0.234391        0.102502  0.110542        0.376261      0.360302
#
#      neutrophils(%)  ...      Urea  lymphocyte count   glucose  (%)lymphocyte  \
# 23        -0.666659  ... -0.319912          0.749888 -0.339121       0.708162
# 52         0.510069  ... -0.590078         -0.107251  0.541544      -0.559811
# 70        -0.545525  ... -0.525238          0.528691  0.175403       0.814459
# 84        -0.216733  ... -0.581072         -0.013242 -0.526045      -0.005548
# 105       -0.597439  ... -0.635106          0.407032 -0.707188       0.533531
# 119       -1.024292  ... -0.436984         -0.129371 -0.655158       1.095387
# 139        0.140900  ... -0.445990          0.069707  0.801696      -0.248513
# 166       -1.526132  ... -0.653117          0.473391 -0.799687       1.566132
# 183       -0.522452  ... -0.617095          0.091826 -0.709115       0.404456
# 209       -0.551293  ... -0.563061          0.556340 -0.855571       0.601865
#
#      D-D dimer  aspartate aminotransferase  \
# 23   -0.632141                   -0.218078
# 52   -0.690078                   -0.272881
# 70   -0.624899                   -0.238629
# 84   -0.591103                   -0.183826
# 105  -0.692492                   -0.286581
# 119  -0.670766                   -0.238629
# 139  -0.705769                   -0.224928
# 166  -0.674387                   -0.259180
# 183  -0.686457                   -0.245479
# 209  -0.714218                   -0.224928
#
#      Amino-terminal brain natriuretic peptide precursor(NT-proBNP)  \
# 23                                           -0.322864
# 52                                           -0.325925
# 70                                           -0.325925
# 84                                           -0.314064
# 105                                          -0.328125
# 119                                          -0.266904
# 139                                          -0.327743
# 166                                          -0.328125
# 183                                          -0.328125
# 209                                          -0.327743
#
#      Lactate dehydrogenase  International standard ratio  \
# 23               -0.658699                     -0.489887
# 52               -0.477936                     -0.489887
# 70               -0.611130                     -0.331016
# 84               -0.556425                     -0.000035
# 105              -0.722917                     -0.211863
# 119              -0.599238                     -0.489887
# 139              -0.404204                     -0.595800
# 166              -0.718160                     -0.410451
# 183              -0.744323                     -0.291298
# 209              -0.625401                     -0.529604
#
#      Hypersensitive c-reactive protein
# 23                           -0.779411
# 52                           -0.472046
# 70                           -0.767017
# 84                           -0.631926
# 105                          -0.801720
# 119                          -0.807917
# 139                          -0.793044
# 166                          -0.804199
# 183                          -0.771975
# 209                          -0.783129
#
# [10 rows x 21 columns]

# %%
A = normalized_train.drop(['id', 'outcome'], axis=1)
B = train['outcome']

cv_shuffle = ShuffleSplit(n_splits=5, test_size=0.2, random_state=1)

# %%
models = {
        "random_forest": RandomForestClassifier(random_state=0),
        "decision_tree" : DecisionTreeClassifier(random_state=0),
        "svm": svm.SVC()
}

scoring = ['accuracy', 'precision', 'f1', 'recall', 'roc_auc']

# %%
metrics = {}
for name in models:
    model = models[name]
    print("training: ", name)
    result = cross_validate(model, A, B, cv=cv_shuffle, n_jobs=-1, scoring=scoring)
    metrics[name] = {}
    for x in result:
        metrics[name][x] = result[x].mean()
    # print(result)
print(metrics)
# Out:
# training:  random_forest
# training:  decision_tree
# training:  svm
# {'random_forest': {'fit_time': 0.2376741886138916, 'score_time': 0.032416582107543945, 'test_accuracy': 0.9946666666666667, 'test_precision': 1.0, 'test_f1': 0.990909090909091, 'test_recall': 0.9826086956521738, 'test_roc_auc': 0.9998327759197323}, 'decision_tree': {'fit_time': 0.009072303771972656, 'score_time': 0.020238924026489257, 'test_accuracy': 0.9493333333333334, 'test_precision': 0.9465694351642618, 'test_f1': 0.9416951524227795, 'test_recall': 0.9383192449111103, 'test_roc_auc': 0.9469375024702773}, 'svm': {'fit_time': 0.008670568466186523, 'score_time': 0.02112569808959961, 'test_accuracy': 0.9653333333333333, 'test_precision': 0.9572222222222223, 'test_f1': 0.9551115331635088, 'test_recall': 0.9534892536295061, 'test_roc_auc': 0.9968584072444706}}

# %%
n=len(metrics['svm'])
r = np.arange(n)
width = 0.25
nr=0

# bars = []
for x in metrics:
    D = metrics[x]
    b = plt.bar(r + width*nr, list(D.values()), width=width, label = x)
    # bars.append(b)
    plt.xticks(range(len(D)), list(D.keys()))
    nr += 1

plt.ylabel("metric value (ms or %)")
plt.legend(models.keys())
plt.xticks(rotation=17)
plt.show()
